# %% [markdown]
# # Cyclomatic Complexity Analysis with Radon

# %%
# Imports
import os
from radon.complexity import cc_visit, cc_rank
import pandas as pd

# %%
# Define the path to the folder containing the algorithms
path = 'Algorithms'

# %%
# Function to analyze the complexity of a Python file
def analyze_file(filepath):
    with open(filepath, 'r', encoding='utf-8') as file:
        code = file.read()
    return cc_visit(code)

# %%
import pandas as pd

# Loop through each Python file
for filename in os.listdir(path):
    if filename.endswith('.py'):
        print(f"\n {filename}")
        results = analyze_file(os.path.join(path, filename))

        # Prepare data for DataFrame
        data = []
        for r in results:
            data.append({
                "Name": r.name,
                "Line": r.lineno,
                "Complexity": r.complexity,
                "Rank": cc_rank(r.complexity),
                "Type": r.__class__.__name__
            })

        # Create and display table
        df = pd.DataFrame(data)
        if not df.empty:
            display(df.sort_values(by="Complexity", ascending=False).reset_index(drop=True))
        else:
            print("No functions or methods detected.")
# Out:
#  graphs.py
#                            Name  Line  Complexity Rank      Type
# 0                 eulerian_path   313           9    B  Function
# 1        betweenness_centrality   240           9    B  Function
# 2               clustering_coef   253           7    B  Function
# 3                      dijkstra   165           6    B  Function
# 4           reachable_with_dist   203           6    B  Function
# 5                 shortest_path   100           6    B  Function
# 6                 DeBruijnGraph   290           6    B     Class
# 7                      distance    85           6    B  Function
# 8                      __init__   350           6    B  Function
# 9                mean_distances   215           5    A  Function
# 10  check_nearly_balanced_graph   297           5    A  Function
# 11                     MN_Graph   202           5    A     Class
# 12               node_has_cycle   115           5    A  Function
# 13                     __init__   142           4    A  Function
# 14                    visualize   183           4    A  Function
# 15                    visualize   131           4    A  Function
# 16                reachable_dfs    74           4    A  Function
# 17                reachable_bfs    63           4    A  Function
# 18                     __init__    10           4    A  Function
# 19                 OverlapGraph   349           4    A     Class
# 20                WeightedGraph   141           4    A     Class
# 21    mean_clustering_perdegree   271           4    A  Function
# 22                seq_from_path   343           3    A  Function
# 23                    get_edges   155           3    A  Function
# 24      search_hamiltonian_path   367           3    A  Function
# 25                seq_from_path   390           3    A  Function
# 26         closeness_centrality   228           3    A  Function
# 27            highest_closeness   235           3    A  Function
# 28             is_in_tuple_list   196           3    A  Function
# 29             get_predecessors    48           3    A  Function
# 30                    get_edges    38           3    A  Function
# 31                        Graph     9           3    A     Class
# 32                     add_edge    22           2    A  Function
# 33                   add_vertex    18           2    A  Function
# 34                  print_graph    28           2    A  Function
# 35         all_clustering_coefs   264           2    A  Function
# 36                     __init__   291           2    A  Function
# 37                    has_cycle   128           2    A  Function
# 38               get_successors   162           2    A  Function
# 39         mean_clustering_coef   267           2    A  Function
# 40                   out_degree    57           1    A  Function
# 41                         size    32           1    A  Function
# 42                       suffix   288           1    A  Function
# 43                       prefix   287           1    A  Function
# 44                       degree    60           1    A  Function
# 45                get_adjacents    51           1    A  Function
# 46                    in_degree    54           1    A  Function
# 47               get_successors    45           1    A  Function
# 48                    get_nodes    35           1    A  Function
# 49                     add_edge   150           1    A  Function
# 50                      get_seq   386           1    A  Function
#  BWT.py
#                   Name  Line  Complexity Rank      Type
# 0          bwt_reverse   145           5    A  Function
# 1  find_ith_occurrence     3           4    A  Function
# 2                  BWT    26           4    A     Class
# 3          bw_matching    94           4    A  Function
# 4             __init__    34           3    A  Function
# 5            build_bwt    46           3    A  Function
# 6   build_suffix_array    60           3    A  Function
# 7      bw_matching_pos   125           3    A  Function
# 8        last_to_first    74           2    A  Function
#  tries.py
#                   Name  Line  Complexity Rank      Type
# 0    prefix_trie_match    50           4    A  Function
# 1          _add_suffix   109           4    A  Function
# 2          add_pattern    27           3    A  Function
# 3                 Trie     1           3    A     Class
# 4    _get_leaves_below   133           3    A  Function
# 5         find_pattern   149           3    A  Function
# 6           SuffixTree    87           3    A     Class
# 7         trie_matches    72           3    A  Function
# 8           print_tree   164           3    A  Function
# 9                build   123           2    A  Function
# 10  trie_from_patterns    41           2    A  Function
# 11          print_trie     9           2    A  Function
# 12            __init__     2           1    A  Function
# 13            add_node    16           1    A  Function
# 14           _add_node    97           1    A  Function
# 15            __init__    88           1    A  Function
#  exaustivo.py
#         Name  Line  Complexity Rank      Type
# 0      motif    37           7    B  Function
# 1      score    33           4    A  Function
# 2    proximo    13           3    A  Function
# 3   enumerar    25           2    A  Function
# 4    Counter     1           2    A     Class
# 5   __init__     2           1    A  Function
# 6  increment     5           1    A  Function
# 7    __int__     8           1    A  Function
#  gibbs.py
#                      Name  Line  Complexity Rank      Type
# 0          gibbs_sampling   117           5    A  Function
# 1                     pwm    54           4    A  Function
# 2             motif_gibbs   168           3    A  Function
# 3             print_motif   156           3    A  Function
# 4           GibbsSampling    10           3    A     Class
# 5          prob_positions    86           3    A  Function
# 6          roulette_wheel   100           3    A  Function
# 7   random_init_positions    35           2    A  Function
# 8                prob_seq    71           2    A  Function
# 9           create_motifs    43           2    A  Function
# 10               __init__    21           1    A  Function
#  auto_finito.py
#                       Name  Line  Complexity Rank      Type
# 0                visualize    63           6    B  Function
# 1         _calculate_state    24           5    A  Function
# 2         AutomatosFinitos     1           4    A     Class
# 3          pattern_overlap    79           3    A  Function
# 4                 __init__     3           3    A  Function
# 5  _build_transition_table    15           3    A  Function
# 6         find_occurrences    51           3    A  Function
# 7            process_input    38           2    A  Function
# 8           get_next_state    73           2    A  Function
#  BB.py
#                Name  Line  Complexity Rank      Type
# 0  branch_and_bound    17           6    B  Function
# 1          score_bb    13           4    A  Function
# 2          motif_bb    42           4    A  Function
# 3           Counter     1           2    A     Class
# 4          __init__     2           1    A  Function
# 5         increment     5           1    A  Function
# 6           __int__     8           1    A  Function
#  assembly.py
#                            Name  Line  Complexity Rank      Type
# 0                 eulerian_path    48           9    B  Function
# 1                 DeBruijnGraph    25           6    B     Class
# 2                      __init__    85           6    B  Function
# 3   check_nearly_balanced_graph    32           5    A  Function
# 4                  OverlapGraph    84           4    A     Class
# 5       search_hamiltonian_path   102           3    A  Function
# 6                 seq_from_path   125           3    A  Function
# 7                 seq_from_path    78           3    A  Function
# 8                      __init__    26           2    A  Function
# 9                   composition     1           2    A  Function
# 10                    in_degree    20           2    A  Function
# 11                  print_graph    16           2    A  Function
# 12                      MyGraph     7           2    A     Class
# 13                     __init__     8           1    A  Function
# 14                       suffix     5           1    A  Function
# 15                       prefix     4           1    A  Function
# 16                    get_nodes    18           1    A  Function
# 17                   out_degree    22           1    A  Function
# 18                   add_vertex    10           1    A  Function
# 19                     add_edge    12           1    A  Function
# 20                      get_seq   121           1    A  Function
